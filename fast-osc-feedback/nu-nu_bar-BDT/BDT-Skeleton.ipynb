# %% [markdown]
# # Boosted Decision Tree Skeleton

# %% [markdown]
# In this cell, split the dataset into _train_ and _test_ samples, using sci-kit learn `train_test_split()`.

# %%
import sys
import os

sys.path.append("/users/oz22897/atmospherics-tools/fast-osc-feedback")

from fastfeedback import *

# %%
data_manager = DataManager("/storage/1/st15719/caf_new_sum.2.6M_weighted.root")
data = data_manager.prepare_data()
# Out:
# Loading data...
# /software/oz22897/miniconda/envs/dune-atmo-osc/lib/python3.12/site-packages/awkward/_nplikes/array_module.py:454: RuntimeWarning: invalid value encountered in cast
#   return self._module.concatenate(arrays, axis=axis, casting="same_kind")
# Finished loading data

# %%
data.head()
# Out:
# shape: (5, 29)
# ┌─────┬─────────────┬─────────────┬────────────┬───┬────────────┬──────────┬──────────┬────────────┐
# │ run ┆ weight      ┆ flux_nue    ┆ flux_numu  ┆ … ┆ direc_true ┆ reco_pdg ┆ recoE    ┆ direc_reco │
# │ --- ┆ ---         ┆ ---         ┆ ---        ┆   ┆ ---        ┆ ---      ┆ ---      ┆ ---        │
# │ i32 ┆ f64         ┆ f64         ┆ f64        ┆   ┆ f32        ┆ i32      ┆ f64      ┆ f64        │
# ╞═════╪═════════════╪═════════════╪════════════╪═══╪════════════╪══════════╪══════════╪════════════╡
# │ 0   ┆ 4.8988936e7 ┆ 90.600863   ┆ 195.635597 ┆ … ┆ 0.807689   ┆ 14       ┆ 0.277068 ┆ 0.801249   │
# │ 0   ┆ 1.40671e7   ┆ 2311.062624 ┆ 4649.65872 ┆ … ┆ -0.721775  ┆ 12       ┆ 0.154129 ┆ 0.626551   │
# │     ┆             ┆             ┆ 4          ┆   ┆            ┆          ┆          ┆            │
# │ 0   ┆ 3.4884324e7 ┆ 0.31472     ┆ 1.171861   ┆ … ┆ 0.758573   ┆ 12       ┆ 3.862075 ┆ 0.879762   │
# │ 0   ┆ 3.2501856e7 ┆ 0.143811    ┆ 0.553702   ┆ … ┆ 0.66354    ┆ 12       ┆ 6.857727 ┆ 0.764922   │
# │ 0   ┆ 4.3541492e7 ┆ 42.007924   ┆ 95.911863  ┆ … ┆ -0.936029  ┆ 0        ┆ 0.785038 ┆ -0.888804  │
# └─────┴─────────────┴─────────────┴────────────┴───┴────────────┴──────────┴──────────┴────────────┘

# %%
from sklearn.model_selection import train_test_split
import numpy as np

# get your input data into an array which is N_events x N_variables
X_data = data

# create an array of truth labels (one per event) - 0 for neutrino, 1 for anti-neutrino
y_data = np.zeros(n_evt)

# split the data into train and test datasets
X_train, X_test, y_train, y_test = train_test_split(
    X_data, y_data, test_size=0.33, random_state=42)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 8
#       5 X_data = data
#       7 # create an array of truth labels (one per event) - 0 for neutrino, 1 for anti-neutrino
# ----> 8 y_data = np.zeros(n_evt)
#      10 # split the data into train and test datasets
#      11 X_train, X_test, y_train, y_test = train_test_split(
#      12     X_data, y_data, test_size=0.33, random_state=42)
#
# NameError: name 'n_evt' is not defined

# %%
from sklearn.model_selection import train_test_split
import numpy as np

# get your input data into an array which is N_events x N_variables
X_data = np.ones((n_evt, n_var))

# create an array of truth labels (one per event) - 0 for neutrino, 1 for anti-neutrino
y_data = np.zeros(n_evt)

# split the data into train and test datasets
X_train, X_test, y_train, y_test = train_test_split(
    X_data, y_data, test_size=0.33, random_state=42)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 5
#       2 import numpy as np
#       4 # get your input data into an array which is N_events x N_variables
# ----> 5 X_data = np.ones((n_evt, n_var))
#       7 # create an array of truth labels (one per event) - 0 for neutrino, 1 for anti-neutrino
#       8 y_data = np.zeros(n_evt)
#
# NameError: name 'n_evt' is not defined

# %% [markdown]
# Train the BDT using the `GradientBoostingClassifier` from sci-kit learn.  Note that `HistGradientBoostingClassifier` is also available, and should be more computationally efficient on large samples (>10k).

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import HistGradientBoostingClassifier

clf = GradientBoostingClassifier(n_estimators=100, learning_rate=1.0, max_depth=1, random_state=0).fit(X_train, y_train)

# %% [markdown]
# Now generate predictions (i.e. log-odds probabilities for each event) for both the test and train samples.

# %%
# this will be a value between 0 and 1 for each event, indicating "probability" that the event is anti-neutrino

# create the result for train datasest
scores_train = clf.decision_function(X_train)

# create the results for test dataset
scores_test = clf.decision_function(X_test)
